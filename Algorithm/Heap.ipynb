# %%
class MaxHeap(object):
    def __inif__(self):
        self.queue = []
        
    def insert(self,n):
        # 맨 마지막에 삽입할 원소 임시 추가
        self.queue.append(n)
        last_index = self.quene.index(self.quene[-1])
        
        # 부모 노드를 타고 올라가며 비교
        while 0 <= last_index:
            parent_index = self.parent(last_index)
            if 0 <= parent_index and self.queue[parent_indx] <= self.queue[last_index]:
                self.swap(last_index,parent_index)
                last_index = parent_index
            else :
                break
            
    
    def parent(self,index):
        return (index-1)//1
    
    def swap(self,last_index,parent_index):
        self.queue[last_index], self.queue[parent_index] = self.queue[parent_index] ,self.queue[last_index]

# %%
class MyClass(object):
    # class attribute
    ck = 1 
    num = 0

    def __init__(self,name,age=17):
        # static attribute
        self.bread = 'samsung'
        # dynamic attribute
        self.name = name
        # default attribute
        self.age = age
        
        # class attrubute 참조
        MyClass.num+=1
        

    # instance method
    def calculate(self):
        self.age +=1

    # static method
    @staticmethod    
    def ckMulti(n):
        return n* MyClass.ck

    # static method
    @staticmethod    
    def class_aka_s(aka):
        MyClass.aka = aka
        
    # class method
    @classmethod
    def class_aka(cls,aka):
        cls.aka = aka

    # class method
    @classmethod
    def print_count(cls):
        print(f'현재 클래스수 {MyClass.num}')

    # class method
    @classmethod
    def creat_class(cls):
        return cls()

class test(MyClass):
    def __init__(self,name):
        self.name = name

# %%
class MyClass(object):
    def __init__(self,name,age=17):
        # static attribute
        self.bread = 'samsung'
        # dynamic attribute
        self.name = name

class test(MyClass):
    def __init__(self,name):
        self.name = name
a = test('kan')
a.bread
